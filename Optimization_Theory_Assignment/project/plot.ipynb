# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !/home/yasheng/Homework/optimization/cvxgen/testsolver
# Out:
# iter     objv        gap       |Ax-b|    |Gx+s-h|    step
#   1   -7.576e+13   2.29e+14   2.47e-01   5.40e+06   0.9504
#   2   -7.047e+11   2.91e+12   2.47e-03   5.41e+04   0.9900
#   3    3.936e+10   3.61e+11   8.79e-06   1.85e+02   0.9966
#   4    5.477e+08   3.84e+09   9.17e-07   1.90e+00   0.9897
#   5    5.489e+06   3.84e+07   3.99e-09   1.90e-02   0.9900
#   6    6.523e+04   4.63e+05   1.81e-10   2.29e-04   0.9880
#   7    1.215e+04   9.04e+04   3.52e-09   4.35e-05   0.8098
#   8    1.537e+04   7.09e+04   1.91e-07   2.55e-05   0.4133
#   9    3.070e+03   1.13e+04   4.39e-08   3.88e-06   0.8482
#  10    5.444e+02   2.50e+03   9.92e-08   7.67e-07   0.8026
#  11    1.718e+02   5.28e+02   5.47e-08   1.46e-07   0.8123
#  12    7.057e+01   1.16e+02   3.19e-07   1.26e-07   0.8518
#  13    2.269e+01   9.14e+01   1.77e-05   7.09e-06   0.5076
#  14    2.621e+01   3.96e+01   8.07e-06   3.25e-06   0.6184
#  15    3.046e+01   4.28e+00   5.37e-06   2.13e-06   0.9185
# ...

# %%
# copied from the output of testsolver.cpp
lateral_deviation = [0.00000,0.00000,0.14988,0.16034,0.19266,0.22350,0.26850,0.33150,0.41562,0.52643,0.66906,0.85087,1.11311,1.47300,1.52818,1.61500,1.61502,1.61500,0.86816,0.68474,0.50396,0.40542,0.33676,0.28582,0.25304]
road_divider = [1 for _ in range(len(lateral_deviation))]
road_shoulder = [-1 for _ in range(len(lateral_deviation))]
center_line = [0 for _ in range(len(lateral_deviation))]
left_bounder = [-3 for _ in range(len(lateral_deviation))]
right_bounder = [3 for _ in range(len(lateral_deviation))]
plt.ylim(-4,4)
plt.xlim(0,25)
plt.plot(left_bounder, 'black', linewidth = 2)
plt.plot(right_bounder, 'black', linewidth = 2)
plt.plot(lateral_deviation,'g', linewidth = 2)
plt.plot(road_divider, 'y',ls = 'dashed')
plt.plot(road_shoulder, 'grey')
plt.plot(center_line, 'black', ls = 'dashed')
plt.plot([15,16],[0,0], ls= 'dotted',lw = 20)
plt.xlabel('Time(s)')
plt.ylabel('Lateral Deviation(m)')
plt.show()

# %%
# copied from the output of testsolver.cpp
lateral_force = [301.11807,319.90819,358.73305,420.41163,508.82687,629.52982,790.44975,1002.28068,1274.49016,1620.95834,2123.70734,2815.67696,2881.31808,2999.99392,2999.79428,2993.36727,1493.40781,1136.90585,905.65854,731.98175,604.79457,516.14446,460.43114,433.42796,433.34553]

road_divider = [1 for _ in range(len(lateral_force))]
road_shoulder = [-1 for _ in range(len(lateral_force))]
center_line = [0 for _ in range(len(lateral_force))]
left_bounder = [-3 for _ in range(len(lateral_force))]
right_bounder = [3 for _ in range(len(lateral_force))]
plt.xlim(0,25)

plt.plot(lateral_force,'g', linewidth = 2)

plt.xlabel('Time(s)')
plt.ylabel('Lateral Force(kN)')
plt.show()

# %%
# copied from the output of testsolver.cpp
lateral_deviation = [0.00000,-0.00000,-0.14736,-0.15763,-0.18941,-0.21972,-0.26394,-0.32582,-0.40851,-0.51803,-0.65750,-0.82777,-1.10234,-1.56284,-1.58727,-1.62352,-1.61976,-1.61745,-0.87120,-0.68500,-0.50424,-0.40547,-0.33692,-0.28606,-0.25333]
road_divider = [1 for _ in range(len(lateral_deviation))]
road_shoulder = [-1 for _ in range(len(lateral_deviation))]
center_line = [0 for _ in range(len(lateral_deviation))]
left_bounder = [-3 for _ in range(len(lateral_deviation))]
right_bounder = [3 for _ in range(len(lateral_deviation))]
plt.ylim(-4,4)
plt.xlim(0,25)
plt.plot(left_bounder, 'black', linewidth = 2)
plt.plot(right_bounder, 'black', linewidth = 2)
plt.plot(lateral_deviation,'g', linewidth = 2)
plt.plot(road_divider, 'y',ls = 'dashed')
plt.plot(road_shoulder, 'grey')
plt.plot(center_line, 'black', ls = 'dashed')
plt.plot([15,16],[0,0], ls= 'dotted',lw = 20)
plt.xlabel('Time(s)')
plt.ylabel('Lateral Deviation(m)')
plt.show()

# %%
# copied from the output of testsolver.cpp
lateral_force = [-296.03946,-314.50671,-352.66465,-413.29047,-500.19009,-618.72849,-776.90996,-986.36096,-1252.44731,-1575.95498,-2104.15281,-2999.99997,-2999.99999,-3000.00000,-3000.00000,-3000.00000,-1500.00001,-1136.65082,-905.66670,-732.17686,-605.12994,-516.59235,-460.97563,-434.05908,-434.05905]

road_divider = [1 for _ in range(len(lateral_force))]
road_shoulder = [-1 for _ in range(len(lateral_force))]
center_line = [0 for _ in range(len(lateral_force))]
left_bounder = [-3 for _ in range(len(lateral_force))]
right_bounder = [3 for _ in range(len(lateral_force))]
plt.xlim(0,25)
plt.plot(lateral_force,'g', linewidth = 2)
plt.xlabel('Time(s)')
plt.ylabel('Lateral Force(kN)')
plt.show()
